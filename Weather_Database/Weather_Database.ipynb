# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 725

# %%
# Import the requests library
import requests

# Import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval")
print("------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i , city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Creat endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, reccord, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
         # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather ["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | vila
# Processing Record 2 of Set 1 | kangaba
# Processing Record 3 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 1 | mar del plata
# Processing Record 5 of Set 1 | ahipara
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | upernavik
# Processing Record 8 of Set 1 | touros
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | havelock
# Processing Record 11 of Set 1 | butaritari
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | itaperuna
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | dana point
# Processing Record 18 of Set 1 | hilo
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 21 of Set 1 | hobyo
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | chokurdakh
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | parnamirim
# Processing Record 26 of Set 1 | carnarvon
# Processing Record 27 of Set 1 | suclayin
# Processing Record 28 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | castro
# Processing Record 32 of Set 1 | kiunga
# Processing Record 33 of Set 1 | praia
# Processing Record 34 of Set 1 | new norfolk
# Processing Record 35 of Set 1 | zabid
# Processing Record 36 of Set 1 | farafangana
# Processing Record 37 of Set 1 | wahiawa
# Processing Record 38 of Set 1 | bengkulu
# Processing Record 39 of Set 1 | port lincoln
# Processing Record 40 of Set 1 | luderitz
# Processing Record 41 of Set 1 | qom
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | khatanga
# Processing Record 44 of Set 1 | hermanus
# Processing Record 45 of Set 1 | bilibino
# Processing Record 46 of Set 1 | rikitea
# Processing Record 47 of Set 1 | umm lajj
# Processing Record 48 of Set 1 | sataua
# City not found. Skipping...
# Processing Record 49 of Set 1 | sao filipe
# Processing Record 50 of Set 1 | male
# Processing Record 1 of Set 2 | barrow
# Processing Record 2 of Set 2 | namatanai
# Processing Record 3 of Set 2 | oudtshoorn
# Processing Record 4 of Set 2 | nikolskoye
# Processing Record 5 of Set 2 | kapaa
# Processing Record 6 of Set 2 | salalah
# Processing Record 7 of Set 2 | hithadhoo
# Processing Record 8 of Set 2 | avarua
# Processing Record 9 of Set 2 | jiwani
# Processing Record 10 of Set 2 | binzhou
# Processing Record 11 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 12 of Set 2 | burica
# City not found. Skipping...
# Processing Record 13 of Set 2 | beroroha
# Processing Record 14 of Set 2 | cape town
# Processing Record 15 of Set 2 | santa cruz
# Processing Record 16 of Set 2 | qaanaaq
# Processing Record 17 of Set 2 | matay
# Processing Record 18 of Set 2 | paamiut
# Processing Record 19 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 2 | jati
# Processing Record 21 of Set 2 | melk
# Processing Record 22 of Set 2 | lagoa
# Processing Record 23 of Set 2 | faanui
# Processing Record 24 of Set 2 | boffa
# Processing Record 25 of Set 2 | butare
# Processing Record 26 of Set 2 | ribeira grande
# Processing Record 27 of Set 2 | port blair
# Processing Record 28 of Set 2 | colac
# Processing Record 29 of Set 2 | arman
# Processing Record 30 of Set 2 | leningradskiy
# Processing Record 31 of Set 2 | corner brook
# Processing Record 32 of Set 2 | mahon
# Processing Record 33 of Set 2 | torbay
# Processing Record 34 of Set 2 | thompson
# Processing Record 35 of Set 2 | cabo san lucas
# Processing Record 36 of Set 2 | saldanha
# Processing Record 37 of Set 2 | saint-philippe
# Processing Record 38 of Set 2 | valkeala
# Processing Record 39 of Set 2 | trelew
# Processing Record 40 of Set 2 | sechura
# Processing Record 41 of Set 2 | atuona
# Processing Record 42 of Set 2 | kjollefjord
# Processing Record 43 of Set 2 | hella
# Processing Record 44 of Set 2 | lompoc
# Processing Record 45 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 2 | provideniya
# Processing Record 47 of Set 2 | bandarbeyla
# Processing Record 48 of Set 2 | masvingo
# Processing Record 49 of Set 2 | havoysund
# Processing Record 50 of Set 2 | oyama
# Processing Record 1 of Set 3 | methoni
# Processing Record 2 of Set 3 | arraial do cabo
# Processing Record 3 of Set 3 | adrar
# Processing Record 4 of Set 3 | myitkyina
# Processing Record 5 of Set 3 | moss point
# Processing Record 6 of Set 3 | yar-sale
# Processing Record 7 of Set 3 | rabaul
# Processing Record 8 of Set 3 | pula
# Processing Record 9 of Set 3 | igbo ora
# Processing Record 10 of Set 3 | tessalit
# Processing Record 11 of Set 3 | cherskiy
# Processing Record 12 of Set 3 | hot springs
# Processing Record 13 of Set 3 | muros
# Processing Record 14 of Set 3 | kahului
# Processing Record 15 of Set 3 | brae
# Processing Record 16 of Set 3 | dikson
# Processing Record 17 of Set 3 | clarence town
# Processing Record 18 of Set 3 | port elizabeth
# Processing Record 19 of Set 3 | ridgecrest
# Processing Record 20 of Set 3 | san patricio
# Processing Record 21 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 22 of Set 3 | lieto
# Processing Record 23 of Set 3 | lasa
# Processing Record 24 of Set 3 | saskylakh
# Processing Record 25 of Set 3 | kruisfontein
# Processing Record 26 of Set 3 | teguldet
# Processing Record 27 of Set 3 | sao jose da coroa grande
# Processing Record 28 of Set 3 | dianopolis
# City not found. Skipping...
# Processing Record 29 of Set 3 | elat
# Processing Record 30 of Set 3 | tasiilaq
# Processing Record 31 of Set 3 | mahebourg
# Processing Record 32 of Set 3 | carcassonne
# Processing Record 33 of Set 3 | kavieng
# Processing Record 34 of Set 3 | kirakira
# Processing Record 35 of Set 3 | hasaki
# Processing Record 36 of Set 3 | katsuura
# Processing Record 37 of Set 3 | sonamura
# Processing Record 38 of Set 3 | necochea
# Processing Record 39 of Set 3 | shakhtinsk
# Processing Record 40 of Set 3 | bethel
# Processing Record 41 of Set 3 | itoman
# Processing Record 42 of Set 3 | luwuk
# Processing Record 43 of Set 3 | ugoofaaru
# Processing Record 44 of Set 3 | senanga
# Processing Record 45 of Set 3 | kaitangata
# Processing Record 46 of Set 3 | pittsburg
# Processing Record 47 of Set 3 | byron bay
# Processing Record 48 of Set 3 | saint-pierre
# Processing Record 49 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 3 | rock sound
# Processing Record 1 of Set 4 | were ilu
# Processing Record 2 of Set 4 | chuy
# Processing Record 3 of Set 4 | tuatapere
# Processing Record 4 of Set 4 | asau
# Processing Record 5 of Set 4 | johnson city
# Processing Record 6 of Set 4 | sola
# Processing Record 7 of Set 4 | udachnyy
# Processing Record 8 of Set 4 | severo-kurilsk
# Processing Record 9 of Set 4 | port-cartier
# Processing Record 10 of Set 4 | mayumba
# Processing Record 11 of Set 4 | labuhan
# Processing Record 12 of Set 4 | meadow lake
# Processing Record 13 of Set 4 | ust-ishim
# Processing Record 14 of Set 4 | buraydah
# Processing Record 15 of Set 4 | galveston
# Processing Record 16 of Set 4 | naze
# Processing Record 17 of Set 4 | coahuayana
# Processing Record 18 of Set 4 | te anau
# Processing Record 19 of Set 4 | goundam
# Processing Record 20 of Set 4 | kodiak
# Processing Record 21 of Set 4 | hami
# Processing Record 22 of Set 4 | eureka
# Processing Record 23 of Set 4 | agadez
# Processing Record 24 of Set 4 | bonfim
# Processing Record 25 of Set 4 | deputatskiy
# Processing Record 26 of Set 4 | sinjah
# City not found. Skipping...
# Processing Record 27 of Set 4 | belgrade
# Processing Record 28 of Set 4 | saint anthony
# Processing Record 29 of Set 4 | koygorodok
# Processing Record 30 of Set 4 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 31 of Set 4 | cozumel
# Processing Record 32 of Set 4 | moville
# Processing Record 33 of Set 4 | banmo
# City not found. Skipping...
# Processing Record 34 of Set 4 | inongo
# Processing Record 35 of Set 4 | turuvekere
# Processing Record 36 of Set 4 | roma
# Processing Record 37 of Set 4 | tokonou
# Processing Record 38 of Set 4 | nuuk
# Processing Record 39 of Set 4 | barabinsk
# Processing Record 40 of Set 4 | jibuti
# Processing Record 41 of Set 4 | wadi maliz
# Processing Record 42 of Set 4 | praia da vitoria
# Processing Record 43 of Set 4 | hambantota
# Processing Record 44 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 4 | mossendjo
# Processing Record 47 of Set 4 | kamaishi
# Processing Record 48 of Set 4 | east london
# Processing Record 49 of Set 4 | matara
# Processing Record 50 of Set 4 | lorengau
# Processing Record 1 of Set 5 | maniitsoq
# Processing Record 2 of Set 5 | esperance
# Processing Record 3 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 5 | aklavik
# Processing Record 5 of Set 5 | tautira
# Processing Record 6 of Set 5 | sistranda
# Processing Record 7 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 5 | nalut
# Processing Record 9 of Set 5 | toora-khem
# Processing Record 10 of Set 5 | ardmore
# Processing Record 11 of Set 5 | paita
# Processing Record 12 of Set 5 | wuwei
# Processing Record 13 of Set 5 | disna
# Processing Record 14 of Set 5 | tazovskiy
# Processing Record 15 of Set 5 | caravelas
# Processing Record 16 of Set 5 | rio gallegos
# Processing Record 17 of Set 5 | hobart
# Processing Record 18 of Set 5 | zabaykalsk
# Processing Record 19 of Set 5 | longyearbyen
# Processing Record 20 of Set 5 | puerto ayora
# Processing Record 21 of Set 5 | port augusta
# Processing Record 22 of Set 5 | mangrol
# Processing Record 23 of Set 5 | morehead
# Processing Record 24 of Set 5 | ahumada
# City not found. Skipping...
# Processing Record 25 of Set 5 | geraldton
# Processing Record 26 of Set 5 | ponta do sol
# Processing Record 27 of Set 5 | abu kamal
# Processing Record 28 of Set 5 | olafsvik
# Processing Record 29 of Set 5 | nanortalik
# Processing Record 30 of Set 5 | calvia
# Processing Record 31 of Set 5 | altay
# Processing Record 32 of Set 5 | caramay
# Processing Record 33 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 5 | chongwe
# Processing Record 35 of Set 5 | auriflama
# Processing Record 36 of Set 5 | dunedin
# Processing Record 37 of Set 5 | gizel
# Processing Record 38 of Set 5 | ixtapa
# Processing Record 39 of Set 5 | sri aman
# Processing Record 40 of Set 5 | san quintin
# Processing Record 41 of Set 5 | dhuri
# Processing Record 42 of Set 5 | marrakesh
# Processing Record 43 of Set 5 | meulaboh
# Processing Record 44 of Set 5 | talara
# Processing Record 45 of Set 5 | innisfail
# Processing Record 46 of Set 5 | tarauaca
# Processing Record 47 of Set 5 | les cayes
# Processing Record 48 of Set 5 | juneau
# Processing Record 49 of Set 5 | alghero
# Processing Record 50 of Set 5 | hofn
# Processing Record 1 of Set 6 | chapais
# Processing Record 2 of Set 6 | kieta
# Processing Record 3 of Set 6 | poum
# Processing Record 4 of Set 6 | palmer
# Processing Record 5 of Set 6 | sitka
# Processing Record 6 of Set 6 | caarapo
# Processing Record 7 of Set 6 | nouadhibou
# Processing Record 8 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 9 of Set 6 | tilichiki
# Processing Record 10 of Set 6 | boende
# Processing Record 11 of Set 6 | inta
# Processing Record 12 of Set 6 | constitucion
# Processing Record 13 of Set 6 | talnakh
# Processing Record 14 of Set 6 | ambatolampy
# Processing Record 15 of Set 6 | tuktoyaktuk
# Processing Record 16 of Set 6 | guaratuba
# Processing Record 17 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 6 | ostrovnoy
# Processing Record 19 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 6 | kenai
# Processing Record 21 of Set 6 | ferme-neuve
# Processing Record 22 of Set 6 | tulum
# Processing Record 23 of Set 6 | syasstroy
# Processing Record 24 of Set 6 | villa guerrero
# Processing Record 25 of Set 6 | lebu
# Processing Record 26 of Set 6 | fevralsk
# City not found. Skipping...
# Processing Record 27 of Set 6 | bagotville
# Processing Record 28 of Set 6 | georgetown
# Processing Record 29 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 6 | kulhudhuffushi
# Processing Record 31 of Set 6 | cockburn town
# Processing Record 32 of Set 6 | shirokiy
# Processing Record 33 of Set 6 | shakawe
# Processing Record 34 of Set 6 | bathsheba
# Processing Record 35 of Set 6 | isangel
# Processing Record 36 of Set 6 | souillac
# Processing Record 37 of Set 6 | panaba
# Processing Record 38 of Set 6 | yabelo
# Processing Record 39 of Set 6 | sovetskiy
# Processing Record 40 of Set 6 | rio de janeiro
# Processing Record 41 of Set 6 | komsomolskiy
# Processing Record 42 of Set 6 | kingsland
# Processing Record 43 of Set 6 | lima
# Processing Record 44 of Set 6 | vanderhoof
# Processing Record 45 of Set 6 | hamilton
# Processing Record 46 of Set 6 | puerto madryn
# Processing Record 47 of Set 6 | neftcala
# Processing Record 48 of Set 6 | harer
# Processing Record 49 of Set 6 | klaksvik
# Processing Record 50 of Set 6 | sehithwa
# Processing Record 1 of Set 7 | sungaipenuh
# Processing Record 2 of Set 7 | saint-louis
# Processing Record 3 of Set 7 | assiniboia
# Processing Record 4 of Set 7 | limbang
# Processing Record 5 of Set 7 | walvis bay
# Processing Record 6 of Set 7 | santa elena
# Processing Record 7 of Set 7 | puerto gaitan
# Processing Record 8 of Set 7 | eskasem
# City not found. Skipping...
# Processing Record 9 of Set 7 | balimo
# City not found. Skipping...
# Processing Record 10 of Set 7 | puerto carreno
# Processing Record 11 of Set 7 | inirida
# Processing Record 12 of Set 7 | krasnyy yar
# Processing Record 13 of Set 7 | nerchinskiy zavod
# Processing Record 14 of Set 7 | phangnga
# Processing Record 15 of Set 7 | gat
# Processing Record 16 of Set 7 | tiksi
# Processing Record 17 of Set 7 | lafia
# Processing Record 18 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 19 of Set 7 | zeya
# Processing Record 20 of Set 7 | quelimane
# Processing Record 21 of Set 7 | ilulissat
# Processing Record 22 of Set 7 | bahia honda
# Processing Record 23 of Set 7 | pavlovskiy
# Processing Record 24 of Set 7 | cidreira
# Processing Record 25 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 7 | anadyr
# Processing Record 27 of Set 7 | namibe
# Processing Record 28 of Set 7 | mecca
# Processing Record 29 of Set 7 | miles city
# Processing Record 30 of Set 7 | sobolevo
# Processing Record 31 of Set 7 | batagay-alyta
# Processing Record 32 of Set 7 | gejiu
# Processing Record 33 of Set 7 | high prairie
# Processing Record 34 of Set 7 | halifax
# Processing Record 35 of Set 7 | skibotn
# Processing Record 36 of Set 7 | yumen
# Processing Record 37 of Set 7 | saint george
# Processing Record 38 of Set 7 | jalu
# Processing Record 39 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 40 of Set 7 | maldonado
# Processing Record 41 of Set 7 | tura
# Processing Record 42 of Set 7 | mtimbira
# Processing Record 43 of Set 7 | high level
# Processing Record 44 of Set 7 | dabakala
# Processing Record 45 of Set 7 | srednekolymsk
# Processing Record 46 of Set 7 | yulara
# Processing Record 47 of Set 7 | pervomayskiy
# Processing Record 48 of Set 7 | yakeshi
# Processing Record 49 of Set 7 | ust-maya
# Processing Record 50 of Set 7 | luanda
# Processing Record 1 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 8 | biak
# Processing Record 3 of Set 8 | nhulunbuy
# Processing Record 4 of Set 8 | aloleng
# Processing Record 5 of Set 8 | skovde
# City not found. Skipping...
# Processing Record 6 of Set 8 | codrington
# Processing Record 7 of Set 8 | cuenca
# Processing Record 8 of Set 8 | libreville
# Processing Record 9 of Set 8 | avera
# Processing Record 10 of Set 8 | del rio
# Processing Record 11 of Set 8 | suez
# Processing Record 12 of Set 8 | sibu
# Processing Record 13 of Set 8 | vila franca do campo
# Processing Record 14 of Set 8 | cayenne
# Processing Record 15 of Set 8 | bambous virieux
# Processing Record 16 of Set 8 | hualmay
# Processing Record 17 of Set 8 | cortland
# Processing Record 18 of Set 8 | leh
# Processing Record 19 of Set 8 | dingle
# Processing Record 20 of Set 8 | rafsanjan
# Processing Record 21 of Set 8 | mount gambier
# Processing Record 22 of Set 8 | pisco
# Processing Record 23 of Set 8 | mount isa
# Processing Record 24 of Set 8 | gambela
# Processing Record 25 of Set 8 | astoria
# Processing Record 26 of Set 8 | wukari
# Processing Record 27 of Set 8 | yeppoon
# Processing Record 28 of Set 8 | vao
# Processing Record 29 of Set 8 | trenggalek
# Processing Record 30 of Set 8 | valparaiso
# Processing Record 31 of Set 8 | narsaq
# Processing Record 32 of Set 8 | bovenden
# Processing Record 33 of Set 8 | santa maria
# Processing Record 34 of Set 8 | vanimo
# Processing Record 35 of Set 8 | kenora
# Processing Record 36 of Set 8 | kavaratti
# Processing Record 37 of Set 8 | rwamagana
# Processing Record 38 of Set 8 | venice
# Processing Record 39 of Set 8 | dongkan
# Processing Record 40 of Set 8 | daru
# Processing Record 41 of Set 8 | coolum beach
# Processing Record 42 of Set 8 | verkhnyaya sinyachikha
# Processing Record 43 of Set 8 | pevek
# Processing Record 44 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 8 | airai
# Processing Record 46 of Set 8 | marquette
# Processing Record 47 of Set 8 | kindu
# Processing Record 48 of Set 8 | sorland
# Processing Record 49 of Set 8 | vanavara
# Processing Record 50 of Set 8 | silvan
# Processing Record 1 of Set 9 | wladyslawowo
# Processing Record 2 of Set 9 | viedma
# Processing Record 3 of Set 9 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 4 of Set 9 | pimenta bueno
# Processing Record 5 of Set 9 | kyaikto
# Processing Record 6 of Set 9 | atambua
# Processing Record 7 of Set 9 | irbit
# Processing Record 8 of Set 9 | vardo
# Processing Record 9 of Set 9 | gladstone
# Processing Record 10 of Set 9 | seybaplaya
# Processing Record 11 of Set 9 | sabang
# Processing Record 12 of Set 9 | tame
# Processing Record 13 of Set 9 | goderich
# Processing Record 14 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 15 of Set 9 | kaeo
# Processing Record 16 of Set 9 | araquari
# Processing Record 17 of Set 9 | masaya
# Processing Record 18 of Set 9 | ukhta
# Processing Record 19 of Set 9 | dalby
# Processing Record 20 of Set 9 | podosinovets
# Processing Record 21 of Set 9 | seymchan
# Processing Record 22 of Set 9 | iqaluit
# Processing Record 23 of Set 9 | matias barbosa
# Processing Record 24 of Set 9 | norman wells
# Processing Record 25 of Set 9 | tungkang
# City not found. Skipping...
# Processing Record 26 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 27 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 28 of Set 9 | tezu
# Processing Record 29 of Set 9 | vidalia
# Processing Record 30 of Set 9 | dingtao
# Processing Record 31 of Set 9 | verkhnyaya khava
# Processing Record 32 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 9 | beira
# Processing Record 34 of Set 9 | mahibadhoo
# Processing Record 35 of Set 9 | temerloh
# Processing Record 36 of Set 9 | mampong
# Processing Record 37 of Set 9 | victoria
# Processing Record 38 of Set 9 | taltal
# Processing Record 39 of Set 9 | lavrentiya
# Processing Record 40 of Set 9 | nyurba
# Processing Record 41 of Set 9 | bambanglipuro
# Processing Record 42 of Set 9 | port macquarie
# Processing Record 43 of Set 9 | play cu
# City not found. Skipping...
# Processing Record 44 of Set 9 | arlit
# Processing Record 45 of Set 9 | shingu
# Processing Record 46 of Set 9 | suluq
# Processing Record 47 of Set 9 | shangzhi
# Processing Record 48 of Set 9 | oume
# Processing Record 49 of Set 9 | coihaique
# Processing Record 50 of Set 9 | abha
# Processing Record 1 of Set 10 | fatikchhari
# City not found. Skipping...
# Processing Record 2 of Set 10 | maun
# Processing Record 3 of Set 10 | harper
# Processing Record 4 of Set 10 | nome
# Processing Record 5 of Set 10 | bonavista
# Processing Record 6 of Set 10 | mogwase
# Processing Record 7 of Set 10 | taoudenni
# Processing Record 8 of Set 10 | brewster
# Processing Record 9 of Set 10 | knysna
# Processing Record 10 of Set 10 | kushiro
# Processing Record 11 of Set 10 | hilton head island
# Processing Record 12 of Set 10 | hirara
# Processing Record 13 of Set 10 | elko
# Processing Record 14 of Set 10 | guaruja
# Processing Record 15 of Set 10 | montepuez
# Processing Record 16 of Set 10 | sakakah
# Processing Record 17 of Set 10 | bauska
# Processing Record 18 of Set 10 | comodoro rivadavia
# Processing Record 19 of Set 10 | sao joao da barra
# Processing Record 20 of Set 10 | naryan-mar
# Processing Record 21 of Set 10 | waipawa
# Processing Record 22 of Set 10 | port hawkesbury
# Processing Record 23 of Set 10 | lubumbashi
# Processing Record 24 of Set 10 | coldwater
# Processing Record 25 of Set 10 | yokadouma
# Processing Record 26 of Set 10 | fukue
# Processing Record 27 of Set 10 | mildura
# Processing Record 28 of Set 10 | coalcoman
# City not found. Skipping...
# Processing Record 29 of Set 10 | grindavik
# Processing Record 30 of Set 10 | morros
# Processing Record 31 of Set 10 | khilok
# Processing Record 32 of Set 10 | aktau
# Processing Record 33 of Set 10 | kaminskiy
# Processing Record 34 of Set 10 | ati
# Processing Record 35 of Set 10 | tias
# Processing Record 36 of Set 10 | fort nelson
# Processing Record 37 of Set 10 | tambopata
# Processing Record 38 of Set 10 | bairiki
# Processing Record 39 of Set 10 | kolarovo
# Processing Record 40 of Set 10 | areosa
# Processing Record 41 of Set 10 | quatre cocos
# Processing Record 42 of Set 10 | brahmapuri
# City not found. Skipping...
# Processing Record 43 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 44 of Set 10 | la ronge
# Processing Record 45 of Set 10 | mersing
# Processing Record 46 of Set 10 | mogadishu
# Processing Record 47 of Set 10 | whitianga
# Processing Record 48 of Set 10 | flinders
# Processing Record 49 of Set 10 | ancud
# Processing Record 50 of Set 10 | novichikha
# Processing Record 1 of Set 11 | lazaro cardenas
# Processing Record 2 of Set 11 | kikwit
# Processing Record 3 of Set 11 | kysyl-syr
# Processing Record 4 of Set 11 | yamada
# Processing Record 5 of Set 11 | fare
# Processing Record 6 of Set 11 | le havre
# Processing Record 7 of Set 11 | jackson
# Processing Record 8 of Set 11 | juterbog
# Processing Record 9 of Set 11 | caala
# Processing Record 10 of Set 11 | makokou
# Processing Record 11 of Set 11 | reconquista
# Processing Record 12 of Set 11 | veseloyarsk
# Processing Record 13 of Set 11 | vrede
# Processing Record 14 of Set 11 | fort-shevchenko
# Processing Record 15 of Set 11 | gedo
# Processing Record 16 of Set 11 | port hardy
# Processing Record 17 of Set 11 | acajutla
# Processing Record 18 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 11 | humaita
# Processing Record 20 of Set 11 | flin flon
# Processing Record 21 of Set 11 | richards bay
# Processing Record 22 of Set 11 | bosaso
# Processing Record 23 of Set 11 | kon tum
# Processing Record 24 of Set 11 | qaqortoq
# Processing Record 25 of Set 11 | gravdal
# Processing Record 26 of Set 11 | porto novo
# Processing Record 27 of Set 11 | nahrin
# Processing Record 28 of Set 11 | belmonte
# Processing Record 29 of Set 11 | san matias
# Processing Record 30 of Set 11 | fortuna
# Processing Record 31 of Set 11 | papar
# Processing Record 32 of Set 11 | kondinskoye
# Processing Record 33 of Set 11 | terrace
# Processing Record 34 of Set 11 | haines junction
# Processing Record 35 of Set 11 | estelle
# Processing Record 36 of Set 11 | kapuskasing
# Processing Record 37 of Set 11 | carballo
# Processing Record 38 of Set 11 | lisala
# Processing Record 39 of Set 11 | ketchikan
# Processing Record 40 of Set 11 | berlevag
# Processing Record 41 of Set 11 | bani
# Processing Record 42 of Set 11 | pangnirtung
# Processing Record 43 of Set 11 | tumaco
# Processing Record 44 of Set 11 | san juan
# Processing Record 45 of Set 11 | san cristobal
# Processing Record 46 of Set 11 | henties bay
# Processing Record 47 of Set 11 | guerrero negro
# Processing Record 48 of Set 11 | slave lake
# Processing Record 49 of Set 11 | pinega
# Processing Record 50 of Set 11 | lekoni
# Processing Record 1 of Set 12 | huarmey
# Processing Record 2 of Set 12 | nabire
# Processing Record 3 of Set 12 | coquimbo
# Processing Record 4 of Set 12 | tiznit
# Processing Record 5 of Set 12 | krasnoselkup
# Processing Record 6 of Set 12 | coari
# Processing Record 7 of Set 12 | svetlaya
# Processing Record 8 of Set 12 | fuling
# Processing Record 9 of Set 12 | ucluelet
# Processing Record 10 of Set 12 | nandu
# Processing Record 11 of Set 12 | kahuta
# Processing Record 12 of Set 12 | laplace
# Processing Record 13 of Set 12 | raudeberg
# Processing Record 14 of Set 12 | bantry
# Processing Record 15 of Set 12 | inhambane
# Processing Record 16 of Set 12 | hwange
# Processing Record 17 of Set 12 | bilma
# Processing Record 18 of Set 12 | champerico
# Processing Record 19 of Set 12 | amahai
# Processing Record 20 of Set 12 | alice springs
# Processing Record 21 of Set 12 | gijon
# Processing Record 22 of Set 12 | singleton
# Processing Record 23 of Set 12 | ust-tsilma
# Processing Record 24 of Set 12 | charters towers
# Processing Record 25 of Set 12 | manadhoo
# Processing Record 26 of Set 12 | burnie
# Processing Record 27 of Set 12 | chiscas
# Processing Record 28 of Set 12 | clyde river
# Processing Record 29 of Set 12 | tatawin
# Processing Record 30 of Set 12 | alta floresta
# Processing Record 31 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 32 of Set 12 | ponta delgada
# Processing Record 33 of Set 12 | kropotkin
# Processing Record 34 of Set 12 | ivanava
# Processing Record 35 of Set 12 | cayce
# Processing Record 36 of Set 12 | poyarkovo
# Processing Record 37 of Set 12 | melilla
# Processing Record 38 of Set 12 | prosyana
# City not found. Skipping...
# Processing Record 39 of Set 12 | talcahuano
# Processing Record 40 of Set 12 | surt
# Processing Record 41 of Set 12 | dauphin
# Processing Record 42 of Set 12 | margate
# Processing Record 43 of Set 12 | itaituba
# Processing Record 44 of Set 12 | yibin
# Processing Record 45 of Set 12 | lukovetskiy
# Processing Record 46 of Set 12 | bardiyah
# Processing Record 47 of Set 12 | beringovskiy
# Processing Record 48 of Set 12 | mayna
# Processing Record 49 of Set 12 | placido de castro
# Processing Record 50 of Set 12 | karpathos
# Processing Record 1 of Set 13 | baykit
# Processing Record 2 of Set 13 | pinotepa de don luis
# Processing Record 3 of Set 13 | najran
# Processing Record 4 of Set 13 | pallasovka
# Processing Record 5 of Set 13 | mana
# Processing Record 6 of Set 13 | turbat
# Processing Record 7 of Set 13 | marsa matruh
# Processing Record 8 of Set 13 | barhi
# Processing Record 9 of Set 13 | quimper
# Processing Record 10 of Set 13 | kabompo
# Processing Record 11 of Set 13 | igunga
# Processing Record 12 of Set 13 | pathein
# Processing Record 13 of Set 13 | teknaf
# Processing Record 14 of Set 13 | henzada
# City not found. Skipping...
# Processing Record 15 of Set 13 | benoy
# Processing Record 16 of Set 13 | yerbogachen
# Processing Record 17 of Set 13 | tres arroyos
# Processing Record 18 of Set 13 | preeceville
# Processing Record 19 of Set 13 | nelson bay
# Processing Record 20 of Set 13 | tabas
# Processing Record 21 of Set 13 | young
# Processing Record 22 of Set 13 | srivardhan
# Processing Record 23 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 13 | nicolas bravo
# Processing Record 25 of Set 13 | ballina
# Processing Record 26 of Set 13 | ambon
# Processing Record 27 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 13 | sao felix do xingu
# Processing Record 29 of Set 13 | arona
# Processing Record 30 of Set 13 | montrose
# Processing Record 31 of Set 13 | pitanga
# Processing Record 32 of Set 13 | lendinara
# Processing Record 33 of Set 13 | paracatu
# Processing Record 34 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 35 of Set 13 | belaya gora
# Processing Record 36 of Set 13 | tecpan
# Processing Record 37 of Set 13 | eyl
# Processing Record 38 of Set 13 | amuntai
# Processing Record 39 of Set 13 | milas
# Processing Record 40 of Set 13 | cravo norte
# Processing Record 41 of Set 13 | port hedland
# Processing Record 42 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 43 of Set 13 | boguchany
# Processing Record 44 of Set 13 | toulepleu
# City not found. Skipping...
# Processing Record 45 of Set 13 | xinzhou
# Processing Record 46 of Set 13 | peniche
# Processing Record 47 of Set 13 | saiha
# Processing Record 48 of Set 13 | nouakchott
# Processing Record 49 of Set 13 | vestmannaeyjar
# Processing Record 50 of Set 13 | martapura
# Processing Record 1 of Set 14 | rodeo
# Processing Record 2 of Set 14 | sharan
# Processing Record 3 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 4 of Set 14 | egvekinot
# Processing Record 5 of Set 14 | marabba
# Processing Record 6 of Set 14 | sept-iles
# Processing Record 7 of Set 14 | soavinandriana
# Processing Record 8 of Set 14 | nemuro
# Processing Record 9 of Set 14 | lokoja
# Processing Record 10 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 14 | ngunguru
# Processing Record 12 of Set 14 | sadove
# Processing Record 13 of Set 14 | faya
# Processing Record 14 of Set 14 | staryy nadym
# Processing Record 15 of Set 14 | saint-leu
# Processing Record 16 of Set 14 | ejura
# Processing Record 17 of Set 14 | camacha
# Processing Record 18 of Set 14 | dudinka
# Processing Record 19 of Set 14 | finschhafen
# Processing Record 20 of Set 14 | tynda
# Processing Record 21 of Set 14 | trinidad
# Processing Record 22 of Set 14 | tome-acu
# City not found. Skipping...
# Processing Record 23 of Set 14 | abu zabad
# Processing Record 24 of Set 14 | ardistan
# City not found. Skipping...
# Processing Record 25 of Set 14 | barcelos
# Processing Record 26 of Set 14 | boden
# Processing Record 27 of Set 14 | mahuva
# Processing Record 28 of Set 14 | tabuk
# Processing Record 29 of Set 14 | ayan
# Processing Record 30 of Set 14 | honiara
# Processing Record 31 of Set 14 | orlik
# Processing Record 32 of Set 14 | kununurra
# Processing Record 33 of Set 14 | bani walid
# Processing Record 34 of Set 14 | wenatchee
# Processing Record 35 of Set 14 | guangyuan
# Processing Record 36 of Set 14 | ternate
# Processing Record 37 of Set 14 | grand forks
# Processing Record 38 of Set 14 | sibolga
# Processing Record 39 of Set 14 | itarema
# Processing Record 40 of Set 14 | alagoa grande
# Processing Record 41 of Set 14 | cotonou
# Processing Record 42 of Set 14 | verkhovazhye
# Processing Record 43 of Set 14 | ferrol
# Processing Record 44 of Set 14 | asosa
# Processing Record 45 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 46 of Set 14 | sibi
# Processing Record 47 of Set 14 | la rioja
# Processing Record 48 of Set 14 | nizhniy odes
# Processing Record 49 of Set 14 | ojinaga
# Processing Record 50 of Set 14 | westport
# Processing Record 1 of Set 15 | tual
# Processing Record 2 of Set 15 | kargala
# Processing Record 3 of Set 15 | agsu
# City not found. Skipping...
# Processing Record 4 of Set 15 | high rock
# Processing Record 5 of Set 15 | andenes
# Processing Record 6 of Set 15 | xiongshi
# City not found. Skipping...
# Processing Record 7 of Set 15 | wattegama
# Processing Record 8 of Set 15 | changli
# Processing Record 9 of Set 15 | veraval
# Processing Record 10 of Set 15 | road town
# Processing Record 11 of Set 15 | temiscaming
# Processing Record 12 of Set 15 | edremit
# Processing Record 13 of Set 15 | abu samrah
# Processing Record 14 of Set 15 | celestun
# Processing Record 15 of Set 15 | bauchi
# Processing Record 16 of Set 15 | prudnik
# Processing Record 17 of Set 15 | baherden
# Processing Record 18 of Set 15 | caceres
# Processing Record 19 of Set 15 | niesky
# Processing Record 20 of Set 15 | dois riachos
# Processing Record 21 of Set 15 | lafiagi
# Processing Record 22 of Set 15 | kasongo-lunda
# Processing Record 23 of Set 15 | tahe
# Processing Record 24 of Set 15 | sao gabriel da cachoeira
# Processing Record 25 of Set 15 | babanusah
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(cities)
# Out:
# 725

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Vila  42.0304   -8.1588     45.73        95          99
# 1        Kangaba  11.9333   -8.4167     67.46        18           7
# 2  Mar Del Plata -38.0023  -57.5575     73.09         1          57
# 3        Ahipara -35.1667  173.1667     72.95        64          95
# 4        Ushuaia -54.8000  -68.3000     44.26        70         100
# 5      Upernavik  72.7868  -56.1549      3.02        99         100
# 6         Touros  -5.1989  -35.4608     77.90        77          99
# 7      Jamestown  42.0970  -79.2353     26.24        56         100
# 8       Havelock  34.8791  -76.9013     64.98        85          20
# 9     Butaritari   3.0707  172.7902     81.73        77          75
#
#    Wind Speed Country Current Description
# 0        2.71      PT     overcast clouds
# 1        6.40      ML           clear sky
# 2        8.01      AR       broken clouds
# 3        6.17      NZ     overcast clouds
# 4        0.00      AR     overcast clouds
# 5        2.37      GL     overcast clouds
# 6       10.51      BR     overcast clouds
# 7       11.99      US     overcast clouds
# 8       12.66      US          few clouds
# 9       17.83      KI       broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Vila      PT  42.0304   -8.1588     45.73        95          99
# 1        Kangaba      ML  11.9333   -8.4167     67.46        18           7
# 2  Mar Del Plata      AR -38.0023  -57.5575     73.09         1          57
# 3        Ahipara      NZ -35.1667  173.1667     72.95        64          95
# 4        Ushuaia      AR -54.8000  -68.3000     44.26        70         100
# 5      Upernavik      GL  72.7868  -56.1549      3.02        99         100
# 6         Touros      BR  -5.1989  -35.4608     77.90        77          99
# 7      Jamestown      US  42.0970  -79.2353     26.24        56         100
# 8       Havelock      US  34.8791  -76.9013     64.98        85          20
# 9     Butaritari      KI   3.0707  172.7902     81.73        77          75
#
#    Wind Speed Current Description
# 0        2.71     overcast clouds
# 1        6.40           clear sky
# 2        8.01       broken clouds
# 3        6.17     overcast clouds
# 4        0.00     overcast clouds
# 5        2.37     overcast clouds
# 6       10.51     overcast clouds
# 7       11.99     overcast clouds
# 8       12.66          few clouds
# 9       17.83       broken clouds

# %%
# Create the output file (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
