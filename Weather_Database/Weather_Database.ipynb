# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitiude and longitude combinations
lats = np.random.uniform(low = -90, high = 90, size = 2000)
lngs = np.random.uniform(low = -180, high = 180, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitiude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 752

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
# Import the requests library
import requests
# Import the API key
from config import weather_api_key

# %%
# Starting URL for weather map API call
url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=' + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6d5bb6524253769c7667eb1940745d5c

# %%
# Import the time library 
import time

# %%
# Create an empty list to hold the weather data
city_data = []
# Print the beginning of the logging
print('Beginning Data Retrieval')
print('------------------------------')

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city
    city_url = url + '&q=' + city.replace(' ', '+')
    
    # Log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for eachof the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        # Append the city information into city_data list
        city_data.append({'City': city.title(),
                         'Lat': city_lat,
                         'Lng': city_lng,
                         'Max Temp': city_max_temp,
                         'Humidity': city_humidity,
                         'Cloudiness': city_clouds,
                         'Wind Speed': city_wind,
                         'Country': city_country,
                         'Current Weather': city_description})
        
# If an error is experienced, skip the city
    except:
        print('City not found. Skipping...')
        pass
# Indicate that Data Loading is complete    
print('------------------------------')
print('Data Retrieval Complete       ')
print('------------------------------')
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | east london
# Processing Record 4 of Set 1 | guerrero negro
# Processing Record 5 of Set 1 | dingle
# Processing Record 6 of Set 1 | tulsipur
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | bambous virieux
# Processing Record 9 of Set 1 | peleduy
# Processing Record 10 of Set 1 | torbay
# Processing Record 11 of Set 1 | ilulissat
# Processing Record 12 of Set 1 | haripur
# Processing Record 13 of Set 1 | istmina
# Processing Record 14 of Set 1 | victoria
# Processing Record 15 of Set 1 | tuktoyaktuk
# Processing Record 16 of Set 1 | portland
# Processing Record 17 of Set 1 | villa alemana
# Processing Record 18 of Set 1 | souillac
# Processing Record 19 of Set 1 | touros
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | taxco
# Processing Record 22 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | besikduzu
# Processing Record 27 of Set 1 | puerto ayora
# Processing Record 28 of Set 1 | misratah
# Processing Record 29 of Set 1 | hithadhoo
# Processing Record 30 of Set 1 | verkhnyaya inta
# Processing Record 31 of Set 1 | san quintin
# Processing Record 32 of Set 1 | bengkulu
# Processing Record 33 of Set 1 | georgetown
# Processing Record 34 of Set 1 | bykovo
# Processing Record 35 of Set 1 | cherskiy
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | kiunga
# Processing Record 38 of Set 1 | mar del plata
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | bredasdorp
# Processing Record 41 of Set 1 | aloleng
# Processing Record 42 of Set 1 | cape town
# Processing Record 43 of Set 1 | tabou
# Processing Record 44 of Set 1 | new norfolk
# Processing Record 45 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 1 | hashimoto
# Processing Record 47 of Set 1 | rawson
# Processing Record 48 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 1 | lavrentiya
# Processing Record 50 of Set 1 | cabo san lucas
# Processing Record 1 of Set 2 | mount gambier
# Processing Record 2 of Set 2 | saskylakh
# Processing Record 3 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 5 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 6 of Set 2 | canchungo
# Processing Record 7 of Set 2 | talnakh
# Processing Record 8 of Set 2 | sao jose da coroa grande
# Processing Record 9 of Set 2 | ichinoseki
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | thompson
# Processing Record 12 of Set 2 | byron bay
# Processing Record 13 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 2 | srednekolymsk
# Processing Record 15 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 2 | chadan
# Processing Record 17 of Set 2 | pacific grove
# Processing Record 18 of Set 2 | carnarvon
# Processing Record 19 of Set 2 | san angelo
# Processing Record 20 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 2 | trincomalee
# Processing Record 22 of Set 2 | belaya gora
# Processing Record 23 of Set 2 | bethel
# Processing Record 24 of Set 2 | xuddur
# Processing Record 25 of Set 2 | praia
# Processing Record 26 of Set 2 | general roca
# Processing Record 27 of Set 2 | serrinha
# Processing Record 28 of Set 2 | karatau
# Processing Record 29 of Set 2 | vila velha
# Processing Record 30 of Set 2 | solano
# Processing Record 31 of Set 2 | college
# Processing Record 32 of Set 2 | luba
# Processing Record 33 of Set 2 | vila franca do campo
# Processing Record 34 of Set 2 | capitan bado
# Processing Record 35 of Set 2 | mount isa
# Processing Record 36 of Set 2 | chokurdakh
# Processing Record 37 of Set 2 | iqaluit
# Processing Record 38 of Set 2 | severo-kurilsk
# Processing Record 39 of Set 2 | la ronge
# Processing Record 40 of Set 2 | lebu
# Processing Record 41 of Set 2 | phayakkhaphum phisai
# Processing Record 42 of Set 2 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 43 of Set 2 | port elizabeth
# Processing Record 44 of Set 2 | yellowknife
# Processing Record 45 of Set 2 | lazaro cardenas
# Processing Record 46 of Set 2 | salalah
# Processing Record 47 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 2 | henties bay
# Processing Record 49 of Set 2 | castro
# Processing Record 50 of Set 2 | sembe
# Processing Record 1 of Set 3 | comodoro rivadavia
# Processing Record 2 of Set 3 | bluff
# Processing Record 3 of Set 3 | williams lake
# Processing Record 4 of Set 3 | ahome
# Processing Record 5 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 3 | jamestown
# Processing Record 7 of Set 3 | babylon
# Processing Record 8 of Set 3 | san patricio
# Processing Record 9 of Set 3 | jinchang
# Processing Record 10 of Set 3 | harper
# Processing Record 11 of Set 3 | cidreira
# Processing Record 12 of Set 3 | kahului
# Processing Record 13 of Set 3 | komsomolskiy
# Processing Record 14 of Set 3 | ribeira grande
# Processing Record 15 of Set 3 | tura
# Processing Record 16 of Set 3 | yumen
# Processing Record 17 of Set 3 | longyearbyen
# Processing Record 18 of Set 3 | lata
# Processing Record 19 of Set 3 | kodiak
# Processing Record 20 of Set 3 | iralaya
# Processing Record 21 of Set 3 | ponta do sol
# Processing Record 22 of Set 3 | broome
# Processing Record 23 of Set 3 | ilinskiy
# Processing Record 24 of Set 3 | nanortalik
# Processing Record 25 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 3 | yulara
# Processing Record 27 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 3 | tasiilaq
# Processing Record 29 of Set 3 | umirim
# Processing Record 30 of Set 3 | pirgos
# Processing Record 31 of Set 3 | rio gallegos
# Processing Record 32 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 3 | cockburn town
# Processing Record 34 of Set 3 | zapolyarnyy
# Processing Record 35 of Set 3 | faanui
# Processing Record 36 of Set 3 | bac lieu
# Processing Record 37 of Set 3 | hambantota
# Processing Record 38 of Set 3 | qaanaaq
# Processing Record 39 of Set 3 | pui
# Processing Record 40 of Set 3 | antofagasta
# Processing Record 41 of Set 3 | kudahuvadhoo
# Processing Record 42 of Set 3 | mahebourg
# Processing Record 43 of Set 3 | zolotukhino
# Processing Record 44 of Set 3 | port lincoln
# Processing Record 45 of Set 3 | chuy
# Processing Record 46 of Set 3 | norfolk
# Processing Record 47 of Set 3 | port hardy
# Processing Record 48 of Set 3 | batagay-alyta
# Processing Record 49 of Set 3 | pinega
# Processing Record 50 of Set 3 | rocha
# Processing Record 1 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 2 of Set 4 | oistins
# Processing Record 3 of Set 4 | norman wells
# Processing Record 4 of Set 4 | tobol
# Processing Record 5 of Set 4 | romny
# Processing Record 6 of Set 4 | trairi
# Processing Record 7 of Set 4 | hilo
# Processing Record 8 of Set 4 | saldanha
# Processing Record 9 of Set 4 | yashkul
# Processing Record 10 of Set 4 | kruisfontein
# Processing Record 11 of Set 4 | alexandria
# Processing Record 12 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 4 | dikson
# Processing Record 14 of Set 4 | muroto
# Processing Record 15 of Set 4 | port augusta
# Processing Record 16 of Set 4 | barrow
# Processing Record 17 of Set 4 | ibotirama
# Processing Record 18 of Set 4 | harrisonville
# Processing Record 19 of Set 4 | talara
# Processing Record 20 of Set 4 | gangakher
# Processing Record 21 of Set 4 | taltal
# Processing Record 22 of Set 4 | hudson bay
# Processing Record 23 of Set 4 | butaritari
# Processing Record 24 of Set 4 | burnie
# Processing Record 25 of Set 4 | troitskoye
# Processing Record 26 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 4 | hay river
# Processing Record 28 of Set 4 | katsuura
# Processing Record 29 of Set 4 | vaini
# Processing Record 30 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 4 | upernavik
# Processing Record 32 of Set 4 | margate
# Processing Record 33 of Set 4 | gizo
# Processing Record 34 of Set 4 | borovskoy
# Processing Record 35 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 4 | taoudenni
# Processing Record 38 of Set 4 | boyolangu
# Processing Record 39 of Set 4 | ahuimanu
# Processing Record 40 of Set 4 | baykit
# Processing Record 41 of Set 4 | tuatapere
# Processing Record 42 of Set 4 | sabha
# Processing Record 43 of Set 4 | porto san giorgio
# Processing Record 44 of Set 4 | sao filipe
# Processing Record 45 of Set 4 | kaitangata
# Processing Record 46 of Set 4 | huaibei
# Processing Record 47 of Set 4 | dhali
# Processing Record 48 of Set 4 | wagga wagga
# Processing Record 49 of Set 4 | zeya
# Processing Record 50 of Set 4 | arraial do cabo
# Processing Record 1 of Set 5 | crotone
# Processing Record 2 of Set 5 | luderitz
# Processing Record 3 of Set 5 | khatanga
# Processing Record 4 of Set 5 | nome
# Processing Record 5 of Set 5 | vrangel
# Processing Record 6 of Set 5 | carutapera
# Processing Record 7 of Set 5 | dongsheng
# Processing Record 8 of Set 5 | acolla
# Processing Record 9 of Set 5 | diego de almagro
# Processing Record 10 of Set 5 | mehamn
# Processing Record 11 of Set 5 | chisineu cris
# City not found. Skipping...
# Processing Record 12 of Set 5 | paamiut
# Processing Record 13 of Set 5 | pisco
# Processing Record 14 of Set 5 | necochea
# Processing Record 15 of Set 5 | wasilla
# Processing Record 16 of Set 5 | charters towers
# Processing Record 17 of Set 5 | chipinge
# Processing Record 18 of Set 5 | pachino
# Processing Record 19 of Set 5 | bara
# Processing Record 20 of Set 5 | kapaa
# Processing Record 21 of Set 5 | naugarzan
# City not found. Skipping...
# Processing Record 22 of Set 5 | saint-philippe
# Processing Record 23 of Set 5 | the valley
# Processing Record 24 of Set 5 | kuching
# Processing Record 25 of Set 5 | sao joao da barra
# Processing Record 26 of Set 5 | bourail
# Processing Record 27 of Set 5 | lufkin
# Processing Record 28 of Set 5 | grindavik
# Processing Record 29 of Set 5 | hermanus
# Processing Record 30 of Set 5 | saint george
# Processing Record 31 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 5 | sisimiut
# Processing Record 33 of Set 5 | plymouth
# Processing Record 34 of Set 5 | lompoc
# Processing Record 35 of Set 5 | san cristobal
# Processing Record 36 of Set 5 | tazovskiy
# Processing Record 37 of Set 5 | gao
# Processing Record 38 of Set 5 | marsh harbour
# Processing Record 39 of Set 5 | hofn
# Processing Record 40 of Set 5 | roebourne
# Processing Record 41 of Set 5 | nioro
# Processing Record 42 of Set 5 | usinsk
# Processing Record 43 of Set 5 | kabompo
# Processing Record 44 of Set 5 | bonthe
# Processing Record 45 of Set 5 | mongoumba
# Processing Record 46 of Set 5 | roma
# Processing Record 47 of Set 5 | tiarei
# Processing Record 48 of Set 5 | neuquen
# Processing Record 49 of Set 5 | turukhansk
# Processing Record 50 of Set 5 | kavieng
# Processing Record 1 of Set 6 | tsiroanomandidy
# Processing Record 2 of Set 6 | puerto ayacucho
# Processing Record 3 of Set 6 | zhumadian
# Processing Record 4 of Set 6 | esperance
# Processing Record 5 of Set 6 | tres lagoas
# Processing Record 6 of Set 6 | maniitsoq
# Processing Record 7 of Set 6 | shakawe
# Processing Record 8 of Set 6 | thaba-tseka
# Processing Record 9 of Set 6 | geraldton
# Processing Record 10 of Set 6 | havoysund
# Processing Record 11 of Set 6 | bogorodskoye
# Processing Record 12 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 14 of Set 6 | chapais
# Processing Record 15 of Set 6 | hervey bay
# Processing Record 16 of Set 6 | port alfred
# Processing Record 17 of Set 6 | vanimo
# Processing Record 18 of Set 6 | kosh-agach
# Processing Record 19 of Set 6 | southbridge
# Processing Record 20 of Set 6 | andilamena
# Processing Record 21 of Set 6 | lubumbashi
# Processing Record 22 of Set 6 | plaeng yao
# Processing Record 23 of Set 6 | kieta
# Processing Record 24 of Set 6 | gigmoto
# Processing Record 25 of Set 6 | gat
# Processing Record 26 of Set 6 | araouane
# Processing Record 27 of Set 6 | marzuq
# Processing Record 28 of Set 6 | fortuna
# Processing Record 29 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 6 | pangai
# Processing Record 31 of Set 6 | kavaratti
# Processing Record 32 of Set 6 | codrington
# Processing Record 33 of Set 6 | glendive
# Processing Record 34 of Set 6 | tiksi
# Processing Record 35 of Set 6 | crab hill
# City not found. Skipping...
# Processing Record 36 of Set 6 | biak
# Processing Record 37 of Set 6 | manado
# Processing Record 38 of Set 6 | tsumeb
# Processing Record 39 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 6 | yoichi
# Processing Record 41 of Set 6 | la quinta
# Processing Record 42 of Set 6 | zhoucheng
# Processing Record 43 of Set 6 | hirara
# Processing Record 44 of Set 6 | ayr
# Processing Record 45 of Set 6 | corrales
# Processing Record 46 of Set 6 | saquarema
# Processing Record 47 of Set 6 | hami
# Processing Record 48 of Set 6 | vernon
# Processing Record 49 of Set 6 | jacareacanga
# Processing Record 50 of Set 6 | maceio
# Processing Record 1 of Set 7 | impfondo
# Processing Record 2 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 3 of Set 7 | kalmar
# Processing Record 4 of Set 7 | marienburg
# Processing Record 5 of Set 7 | lethem
# Processing Record 6 of Set 7 | tenenkou
# Processing Record 7 of Set 7 | laerdalsoyri
# Processing Record 8 of Set 7 | ostrovnoy
# Processing Record 9 of Set 7 | panaba
# Processing Record 10 of Set 7 | bereda
# Processing Record 11 of Set 7 | sao domingos
# Processing Record 12 of Set 7 | airai
# Processing Record 13 of Set 7 | isangel
# Processing Record 14 of Set 7 | abonnema
# Processing Record 15 of Set 7 | soe
# Processing Record 16 of Set 7 | los llanos de aridane
# Processing Record 17 of Set 7 | ahipara
# Processing Record 18 of Set 7 | owando
# Processing Record 19 of Set 7 | teyateyaneng
# Processing Record 20 of Set 7 | zhaozhou
# Processing Record 21 of Set 7 | leningradskiy
# Processing Record 22 of Set 7 | shelburne
# Processing Record 23 of Set 7 | sitka
# Processing Record 24 of Set 7 | cervo
# Processing Record 25 of Set 7 | ventspils
# Processing Record 26 of Set 7 | avera
# Processing Record 27 of Set 7 | gaborone
# Processing Record 28 of Set 7 | kakonko
# Processing Record 29 of Set 7 | sola
# Processing Record 30 of Set 7 | new glasgow
# Processing Record 31 of Set 7 | daru
# Processing Record 32 of Set 7 | port blair
# Processing Record 33 of Set 7 | vaerlose
# Processing Record 34 of Set 7 | savannah bight
# Processing Record 35 of Set 7 | matara
# Processing Record 36 of Set 7 | beringovskiy
# Processing Record 37 of Set 7 | skhisma
# Processing Record 38 of Set 7 | eldikan
# City not found. Skipping...
# Processing Record 39 of Set 7 | yeletskiy
# City not found. Skipping...
# Processing Record 40 of Set 7 | hirata
# Processing Record 41 of Set 7 | tomatlan
# Processing Record 42 of Set 7 | bako
# Processing Record 43 of Set 7 | fort saint james
# Processing Record 44 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 7 | pechora
# Processing Record 47 of Set 7 | jambi
# Processing Record 48 of Set 7 | bossembele
# City not found. Skipping...
# Processing Record 49 of Set 7 | ancud
# Processing Record 50 of Set 7 | kapustin yar
# Processing Record 1 of Set 8 | carrefour
# Processing Record 2 of Set 8 | taitung
# Processing Record 3 of Set 8 | anadyr
# Processing Record 4 of Set 8 | puerto carreno
# Processing Record 5 of Set 8 | guaiba
# Processing Record 6 of Set 8 | qaqortoq
# Processing Record 7 of Set 8 | ugoofaaru
# Processing Record 8 of Set 8 | hasaki
# Processing Record 9 of Set 8 | bilaspur
# Processing Record 10 of Set 8 | mnogovershinnyy
# Processing Record 11 of Set 8 | bull savanna
# Processing Record 12 of Set 8 | banda aceh
# Processing Record 13 of Set 8 | pemangkat
# Processing Record 14 of Set 8 | coquimbo
# Processing Record 15 of Set 8 | takoradi
# Processing Record 16 of Set 8 | faya
# Processing Record 17 of Set 8 | whitehorse
# Processing Record 18 of Set 8 | monrovia
# Processing Record 19 of Set 8 | lagoa
# Processing Record 20 of Set 8 | alghero
# Processing Record 21 of Set 8 | richards bay
# Processing Record 22 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 24 of Set 8 | nouadhibou
# Processing Record 25 of Set 8 | shetpe
# Processing Record 26 of Set 8 | zirandaro
# Processing Record 27 of Set 8 | amahai
# Processing Record 28 of Set 8 | nikolskoye
# Processing Record 29 of Set 8 | maneadero
# Processing Record 30 of Set 8 | ligayan
# Processing Record 31 of Set 8 | nuuk
# Processing Record 32 of Set 8 | paso de patria
# Processing Record 33 of Set 8 | ubinskoye
# Processing Record 34 of Set 8 | yerbogachen
# Processing Record 35 of Set 8 | clinton
# Processing Record 36 of Set 8 | dwarka
# Processing Record 37 of Set 8 | lublin
# Processing Record 38 of Set 8 | sabang
# Processing Record 39 of Set 8 | mirnyy
# Processing Record 40 of Set 8 | asyut
# Processing Record 41 of Set 8 | somerset west
# Processing Record 42 of Set 8 | karakendzha
# City not found. Skipping...
# Processing Record 43 of Set 8 | rudsar
# Processing Record 44 of Set 8 | ndele
# Processing Record 45 of Set 8 | peski
# Processing Record 46 of Set 8 | camabatela
# Processing Record 47 of Set 8 | brigantine
# Processing Record 48 of Set 8 | yicheng
# Processing Record 49 of Set 8 | baghdad
# Processing Record 50 of Set 8 | macusani
# Processing Record 1 of Set 9 | hamilton
# Processing Record 2 of Set 9 | aripuana
# Processing Record 3 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 4 of Set 9 | egvekinot
# Processing Record 5 of Set 9 | mbeya
# Processing Record 6 of Set 9 | mezen
# Processing Record 7 of Set 9 | rantepao
# Processing Record 8 of Set 9 | conceicao do araguaia
# Processing Record 9 of Set 9 | padang
# Processing Record 10 of Set 9 | khabarovsk
# Processing Record 11 of Set 9 | luancheng
# Processing Record 12 of Set 9 | bogo
# Processing Record 13 of Set 9 | provideniya
# Processing Record 14 of Set 9 | muhos
# Processing Record 15 of Set 9 | deputatskiy
# Processing Record 16 of Set 9 | hit
# Processing Record 17 of Set 9 | beira
# Processing Record 18 of Set 9 | young
# Processing Record 19 of Set 9 | xiaoweizhai
# Processing Record 20 of Set 9 | sorrento
# Processing Record 21 of Set 9 | oyama
# Processing Record 22 of Set 9 | asau
# Processing Record 23 of Set 9 | abyek
# Processing Record 24 of Set 9 | aklavik
# Processing Record 25 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 9 | yar-sale
# Processing Record 27 of Set 9 | vestmannaeyjar
# Processing Record 28 of Set 9 | katobu
# Processing Record 29 of Set 9 | lorengau
# Processing Record 30 of Set 9 | bafq
# Processing Record 31 of Set 9 | nishihara
# Processing Record 32 of Set 9 | jonesboro
# Processing Record 33 of Set 9 | erdenet
# Processing Record 34 of Set 9 | prykolotne
# Processing Record 35 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 36 of Set 9 | khilok
# Processing Record 37 of Set 9 | bertoua
# Processing Record 38 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 39 of Set 9 | harrismith
# Processing Record 40 of Set 9 | coos bay
# Processing Record 41 of Set 9 | santa cruz cabralia
# Processing Record 42 of Set 9 | lima
# Processing Record 43 of Set 9 | biltine
# Processing Record 44 of Set 9 | jasper
# Processing Record 45 of Set 9 | charyshskoye
# Processing Record 46 of Set 9 | urumqi
# Processing Record 47 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 48 of Set 9 | dudinka
# Processing Record 49 of Set 9 | laiagam
# City not found. Skipping...
# Processing Record 50 of Set 9 | annau
# Processing Record 1 of Set 10 | tabuk
# Processing Record 2 of Set 10 | alofi
# Processing Record 3 of Set 10 | skvyra
# Processing Record 4 of Set 10 | haines junction
# Processing Record 5 of Set 10 | mantua
# Processing Record 6 of Set 10 | meulaboh
# Processing Record 7 of Set 10 | ulladulla
# Processing Record 8 of Set 10 | kushalgarh
# Processing Record 9 of Set 10 | roald
# Processing Record 10 of Set 10 | linxia
# Processing Record 11 of Set 10 | iracoubo
# Processing Record 12 of Set 10 | danielskuil
# Processing Record 13 of Set 10 | markha
# Processing Record 14 of Set 10 | caravelas
# Processing Record 15 of Set 10 | hoquiam
# Processing Record 16 of Set 10 | lasa
# Processing Record 17 of Set 10 | nantucket
# Processing Record 18 of Set 10 | inhambane
# Processing Record 19 of Set 10 | fjerritslev
# Processing Record 20 of Set 10 | plettenberg bay
# Processing Record 21 of Set 10 | lodja
# Processing Record 22 of Set 10 | blagoyevo
# Processing Record 23 of Set 10 | svetlogorsk
# Processing Record 24 of Set 10 | muros
# Processing Record 25 of Set 10 | nushki
# Processing Record 26 of Set 10 | piacabucu
# Processing Record 27 of Set 10 | high level
# Processing Record 28 of Set 10 | raga
# Processing Record 29 of Set 10 | awbari
# Processing Record 30 of Set 10 | novoagansk
# Processing Record 31 of Set 10 | gogrial
# Processing Record 32 of Set 10 | koratagere
# Processing Record 33 of Set 10 | cirpan
# City not found. Skipping...
# Processing Record 34 of Set 10 | rio branco
# Processing Record 35 of Set 10 | ardistan
# City not found. Skipping...
# Processing Record 36 of Set 10 | balikpapan
# Processing Record 37 of Set 10 | adrar
# Processing Record 38 of Set 10 | eftimie murgu
# Processing Record 39 of Set 10 | imeni poliny osipenko
# Processing Record 40 of Set 10 | ordu
# Processing Record 41 of Set 10 | kazanka
# Processing Record 42 of Set 10 | bandarbeyla
# Processing Record 43 of Set 10 | sibu
# Processing Record 44 of Set 10 | yei
# Processing Record 45 of Set 10 | falmouth
# Processing Record 46 of Set 10 | tamandare
# Processing Record 47 of Set 10 | namibe
# Processing Record 48 of Set 10 | akhisar
# Processing Record 49 of Set 10 | wanning
# Processing Record 50 of Set 10 | aksarka
# Processing Record 1 of Set 11 | kilembe
# Processing Record 2 of Set 11 | kosovska mitrovica
# Processing Record 3 of Set 11 | bairiki
# Processing Record 4 of Set 11 | nueve de julio
# Processing Record 5 of Set 11 | port huron
# Processing Record 6 of Set 11 | te anau
# Processing Record 7 of Set 11 | ayan
# Processing Record 8 of Set 11 | ketchikan
# Processing Record 9 of Set 11 | fairbanks
# Processing Record 10 of Set 11 | clonakilty
# Processing Record 11 of Set 11 | buchanan
# Processing Record 12 of Set 11 | nova vicosa
# Processing Record 13 of Set 11 | sumy
# Processing Record 14 of Set 11 | kijang
# Processing Record 15 of Set 11 | batemans bay
# Processing Record 16 of Set 11 | pangkalanbuun
# Processing Record 17 of Set 11 | micheweni
# Processing Record 18 of Set 11 | tachi
# City not found. Skipping...
# Processing Record 19 of Set 11 | neiafu
# Processing Record 20 of Set 11 | hiriyur
# Processing Record 21 of Set 11 | kachug
# Processing Record 22 of Set 11 | diffa
# Processing Record 23 of Set 11 | terra rica
# Processing Record 24 of Set 11 | prince rupert
# Processing Record 25 of Set 11 | sobolevo
# Processing Record 26 of Set 11 | pong
# Processing Record 27 of Set 11 | treinta y tres
# Processing Record 28 of Set 11 | sarlat-la-caneda
# Processing Record 29 of Set 11 | havre-saint-pierre
# Processing Record 30 of Set 11 | jarjis
# City not found. Skipping...
# Processing Record 31 of Set 11 | bilibino
# Processing Record 32 of Set 11 | baiyin
# Processing Record 33 of Set 11 | ngawi
# Processing Record 34 of Set 11 | constitucion
# Processing Record 35 of Set 11 | bambari
# Processing Record 36 of Set 11 | torres
# Processing Record 37 of Set 11 | keetmanshoop
# Processing Record 38 of Set 11 | sawtell
# Processing Record 39 of Set 11 | clyde river
# Processing Record 40 of Set 11 | plouzane
# Processing Record 41 of Set 11 | searcy
# Processing Record 42 of Set 11 | keshan
# City not found. Skipping...
# Processing Record 43 of Set 11 | kailua
# Processing Record 44 of Set 11 | manakara
# Processing Record 45 of Set 11 | sinnamary
# Processing Record 46 of Set 11 | elko
# Processing Record 47 of Set 11 | tongzi
# Processing Record 48 of Set 11 | sistranda
# Processing Record 49 of Set 11 | havre
# Processing Record 50 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 1 of Set 12 | requena
# Processing Record 2 of Set 12 | borba
# Processing Record 3 of Set 12 | beeskow
# Processing Record 4 of Set 12 | goundam
# Processing Record 5 of Set 12 | merke
# Processing Record 6 of Set 12 | baturaja
# Processing Record 7 of Set 12 | tessalit
# Processing Record 8 of Set 12 | sungaipenuh
# Processing Record 9 of Set 12 | sofiysk
# City not found. Skipping...
# Processing Record 10 of Set 12 | port-gentil
# Processing Record 11 of Set 12 | cap-aux-meules
# Processing Record 12 of Set 12 | kaseda
# Processing Record 13 of Set 12 | saint-francois
# Processing Record 14 of Set 12 | acapulco
# Processing Record 15 of Set 12 | nouakchott
# Processing Record 16 of Set 12 | batagay
# Processing Record 17 of Set 12 | vostok
# Processing Record 18 of Set 12 | kota bahru
# Processing Record 19 of Set 12 | morti
# City not found. Skipping...
# Processing Record 20 of Set 12 | weligama
# Processing Record 21 of Set 12 | husavik
# Processing Record 22 of Set 12 | wamba
# Processing Record 23 of Set 12 | katherine
# Processing Record 24 of Set 12 | njeru
# Processing Record 25 of Set 12 | mirabad
# Processing Record 26 of Set 12 | yomitan
# City not found. Skipping...
# Processing Record 27 of Set 12 | camacha
# Processing Record 28 of Set 12 | harbour breton
# Processing Record 29 of Set 12 | gannavaram
# Processing Record 30 of Set 12 | san pedro de macoris
# Processing Record 31 of Set 12 | westport
# Processing Record 32 of Set 12 | saint-augustin
# Processing Record 33 of Set 12 | raymond
# Processing Record 34 of Set 12 | opuwo
# Processing Record 35 of Set 12 | sibiti
# Processing Record 36 of Set 12 | neosho
# Processing Record 37 of Set 12 | bonavista
# Processing Record 38 of Set 12 | lanxi
# Processing Record 39 of Set 12 | kirakira
# Processing Record 40 of Set 12 | jibuti
# Processing Record 41 of Set 12 | tual
# Processing Record 42 of Set 12 | okhotsk
# Processing Record 43 of Set 12 | opotiki
# Processing Record 44 of Set 12 | panchagarh
# Processing Record 45 of Set 12 | raudeberg
# Processing Record 46 of Set 12 | mahanoro
# Processing Record 47 of Set 12 | mahina
# Processing Record 48 of Set 12 | izhma
# Processing Record 49 of Set 12 | batticaloa
# Processing Record 50 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 1 of Set 13 | axim
# Processing Record 2 of Set 13 | dukat
# Processing Record 3 of Set 13 | neapolis
# Processing Record 4 of Set 13 | kholodnyy
# Processing Record 5 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 6 of Set 13 | nhulunbuy
# Processing Record 7 of Set 13 | taseyevo
# Processing Record 8 of Set 13 | bay city
# Processing Record 9 of Set 13 | sorland
# Processing Record 10 of Set 13 | khovu-aksy
# Processing Record 11 of Set 13 | winnemucca
# Processing Record 12 of Set 13 | quatre cocos
# Processing Record 13 of Set 13 | payson
# Processing Record 14 of Set 13 | brae
# Processing Record 15 of Set 13 | buala
# Processing Record 16 of Set 13 | suhbaatar
# Processing Record 17 of Set 13 | vao
# Processing Record 18 of Set 13 | yako
# Processing Record 19 of Set 13 | blackwater
# Processing Record 20 of Set 13 | ixtapa
# Processing Record 21 of Set 13 | okha
# Processing Record 22 of Set 13 | koundara
# Processing Record 23 of Set 13 | vaitape
# Processing Record 24 of Set 13 | palizada
# Processing Record 25 of Set 13 | monroe
# Processing Record 26 of Set 13 | valkla
# Processing Record 27 of Set 13 | lander
# Processing Record 28 of Set 13 | sovetskiy
# Processing Record 29 of Set 13 | caluquembe
# Processing Record 30 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 31 of Set 13 | pangnirtung
# Processing Record 32 of Set 13 | hokitika
# Processing Record 33 of Set 13 | chimoio
# Processing Record 34 of Set 13 | narsaq
# Processing Record 35 of Set 13 | kapuskasing
# Processing Record 36 of Set 13 | mandalgovi
# Processing Record 37 of Set 13 | chama
# Processing Record 38 of Set 13 | san luis
# Processing Record 39 of Set 13 | cerrito
# Processing Record 40 of Set 13 | port hawkesbury
# Processing Record 41 of Set 13 | ninghai
# Processing Record 42 of Set 13 | naze
# Processing Record 43 of Set 13 | stranraer
# Processing Record 44 of Set 13 | calarasi
# Processing Record 45 of Set 13 | ustrzyki dolne
# Processing Record 46 of Set 13 | oksfjord
# Processing Record 47 of Set 13 | ubauro
# Processing Record 48 of Set 13 | tinskoy
# Processing Record 49 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 50 of Set 13 | olot
# Processing Record 1 of Set 14 | saravan
# Processing Record 2 of Set 14 | morondava
# Processing Record 3 of Set 14 | florianopolis
# Processing Record 4 of Set 14 | atka
# City not found. Skipping...
# Processing Record 5 of Set 14 | oktyabrskiy
# Processing Record 6 of Set 14 | port antonio
# Processing Record 7 of Set 14 | yingshang
# City not found. Skipping...
# Processing Record 8 of Set 14 | kalianget
# Processing Record 9 of Set 14 | esmeraldas
# Processing Record 10 of Set 14 | flinders
# Processing Record 11 of Set 14 | berlevag
# Processing Record 12 of Set 14 | tahoua
# Processing Record 13 of Set 14 | shingu
# Processing Record 14 of Set 14 | bathsheba
# Processing Record 15 of Set 14 | kidal
# Processing Record 16 of Set 14 | caraballeda
# Processing Record 17 of Set 14 | kollam
# Processing Record 18 of Set 14 | port macquarie
# Processing Record 19 of Set 14 | gambela
# Processing Record 20 of Set 14 | la orilla
# Processing Record 21 of Set 14 | kapoeta
# Processing Record 22 of Set 14 | amboise
# Processing Record 23 of Set 14 | satuk
# Processing Record 24 of Set 14 | shkotovo-26
# City not found. Skipping...
# Processing Record 25 of Set 14 | soure
# Processing Record 26 of Set 14 | belmonte
# Processing Record 27 of Set 14 | tapiramuta
# Processing Record 28 of Set 14 | ambovombe
# Processing Record 29 of Set 14 | umm lajj
# Processing Record 30 of Set 14 | olinda
# Processing Record 31 of Set 14 | severo-yeniseyskiy
# Processing Record 32 of Set 14 | meiganga
# Processing Record 33 of Set 14 | houston
# Processing Record 34 of Set 14 | nelson bay
# Processing Record 35 of Set 14 | santa rosa
# Processing Record 36 of Set 14 | bridlington
# Processing Record 37 of Set 14 | aksu
# Processing Record 38 of Set 14 | arrecife
# Processing Record 39 of Set 14 | jiuquan
# Processing Record 40 of Set 14 | pinahat
# Processing Record 41 of Set 14 | kodinsk
# Processing Record 42 of Set 14 | surt
# Processing Record 43 of Set 14 | unai
# Processing Record 44 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 45 of Set 14 | fairhope
# Processing Record 46 of Set 14 | udon thani
# Processing Record 47 of Set 14 | khandbari
# Processing Record 48 of Set 14 | zhanaozen
# Processing Record 49 of Set 14 | aquin
# Processing Record 50 of Set 14 | ystad
# Processing Record 1 of Set 15 | novobirilyussy
# Processing Record 2 of Set 15 | christchurch
# Processing Record 3 of Set 15 | hadejia
# Processing Record 4 of Set 15 | ribeira brava
# Processing Record 5 of Set 15 | partizanskoye
# Processing Record 6 of Set 15 | nyuksenitsa
# Processing Record 7 of Set 15 | lashio
# Processing Record 8 of Set 15 | dhidhdhoo
# Processing Record 9 of Set 15 | jumla
# Processing Record 10 of Set 15 | real
# Processing Record 11 of Set 15 | noyabrsk
# Processing Record 12 of Set 15 | dajabon
# Processing Record 13 of Set 15 | port moresby
# Processing Record 14 of Set 15 | poletayevo
# Processing Record 15 of Set 15 | altamira
# Processing Record 16 of Set 15 | tubruq
# City not found. Skipping...
# Processing Record 17 of Set 15 | karachi
# Processing Record 18 of Set 15 | abu samrah
# Processing Record 19 of Set 15 | brooks
# Processing Record 20 of Set 15 | tautira
# Processing Record 21 of Set 15 | djibo
# Processing Record 22 of Set 15 | laguna
# Processing Record 23 of Set 15 | keflavik
# Processing Record 24 of Set 15 | victor harbor
# Processing Record 25 of Set 15 | san carlos de bariloche
# Processing Record 26 of Set 15 | fukue
# Processing Record 27 of Set 15 | peniche
# Processing Record 28 of Set 15 | progreso
# Processing Record 29 of Set 15 | suntar
# Processing Record 30 of Set 15 | san juan
# Processing Record 31 of Set 15 | pevek
# Processing Record 32 of Set 15 | newport
# Processing Record 33 of Set 15 | usevya
# Processing Record 34 of Set 15 | sabibah
# City not found. Skipping...
# Processing Record 35 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 36 of Set 15 | nosy varika
# Processing Record 37 of Set 15 | goure
# Processing Record 38 of Set 15 | sorong
# Processing Record 39 of Set 15 | soyo
# Processing Record 40 of Set 15 | tungkang
# City not found. Skipping...
# Processing Record 41 of Set 15 | hidalgotitlan
# Processing Record 42 of Set 15 | yarmouth
# Processing Record 43 of Set 15 | maningrida
# Processing Record 44 of Set 15 | hubli
# Processing Record 45 of Set 15 | mogadishu
# Processing Record 46 of Set 15 | freeport
# Processing Record 47 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 48 of Set 15 | evensk
# Processing Record 49 of Set 15 | hualmay
# Processing Record 50 of Set 15 | matamoros
# Processing Record 1 of Set 16 | nagar
# Processing Record 2 of Set 16 | cap malheureux
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
len(city_data)
# Out:
# 686

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Busselton -33.6500  115.3333     69.08        74         100
# 1            Avarua -21.2078 -159.7750     80.65        83          20
# 2       East London -33.0153   27.9116     58.14        72          20
# 3    Guerrero Negro  27.9769 -114.0611     70.72        39          71
# 4            Dingle  10.9995  122.6711     76.55        89         100
# ..              ...      ...       ...       ...       ...         ...
# 681          Evensk  61.9500  159.2333     18.86        75         100
# 682         Hualmay -11.0964  -77.6139     67.60        89          75
# 683       Matamoros  25.5333 -103.2500     63.50        23          72
# 684           Nagar  27.4333   77.1000    105.55         4           0
# 685  Cap Malheureux -19.9842   57.6142     81.46        79          34
#
#      Wind Speed Country   Current Weather
# 0         14.76      AU   overcast clouds
# 1          6.91      CK        few clouds
# 2          5.75      ZA        few clouds
# 3          6.51      MX     broken clouds
# 4          7.61      PH   overcast clouds
# ..          ...     ...               ...
# 681        2.82      RU   overcast clouds
# 682        8.01      PE     broken clouds
# 683        8.93      MX     broken clouds
# 684        6.85      IN         clear sky
# 685        8.99      MU  scattered clouds
#
# [686 rows x 9 columns]

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Weather']
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Busselton      AU -33.6500  115.3333     69.08        74         100
# 1          Avarua      CK -21.2078 -159.7750     80.65        83          20
# 2     East London      ZA -33.0153   27.9116     58.14        72          20
# 3  Guerrero Negro      MX  27.9769 -114.0611     70.72        39          71
# 4          Dingle      PH  10.9995  122.6711     76.55        89         100
#
#    Wind Speed  Current Weather
# 0       14.76  overcast clouds
# 1        6.91       few clouds
# 2        5.75       few clouds
# 3        6.51    broken clouds
# 4        7.61  overcast clouds

# %%
# Create the output file (CSV)
output_data_file = "/Users/andreadarrah/Desktop/classwork/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
